# %% [markdown]
# **NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.**
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps**
# * Create a figure object called fig using plt.figure()
# * Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# * Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
fig = plt.figure(dpi=70)

ax = fig.add_axes([0,0,1,1])
ax.yaxis.set_major_locator(plt.MultipleLocator(50))
ax.plot(x,y, color='blue')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('title')
plt.show()

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure(dpi=70, figsize=(6.5,4))

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])
ax2.xaxis.set_major_locator(plt.MultipleLocator(0.2))
ax2.yaxis.set_major_locator(plt.MultipleLocator(0.2))

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
ax2.xaxis.set_major_locator(plt.MultipleLocator(20))
ax2.yaxis.set_major_locator(plt.MultipleLocator(50))
ax1.plot(x,y, 'brown')
ax2.plot(x,y, 'brown')
fig

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure(dpi=70, figsize=(6.3, 4.5))
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
ax1.plot(x,z,'b')
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2.plot(x,y,'b')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('zoom')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])

fig

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2 , dpi=70, figsize=(6.2, 4))

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
axes[0].plot(x,y, color='blue', lw=1.5, ls='--')
axes[1].plot(x,z, color='red', lw=1.5, ls='-')
fig

# %% [markdown]
# **See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8.5,1.3))

axes[0].plot(x,y, color='blue', lw=3, ls='-')
axes[0].yaxis.set_major_locator(plt.MultipleLocator(50))
axes[0].tick_params(axis='y', labelsize=8)
axes[0].tick_params(axis='x', labelsize=8)

axes[1].plot(x,z, color='red', lw=3, ls='--')
axes[1].yaxis.set_major_locator(plt.MultipleLocator(2500))
axes[1].tick_params(axis='y', labelsize=8)
axes[1].tick_params(axis='x', labelsize=8)

# %% [markdown]
# # Great Job!
